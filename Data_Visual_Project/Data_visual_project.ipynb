# %% [markdown]
# <a href="https://colab.research.google.com/github/AlkaAttri/Python-ML-Learning/blob/main/Data_Visual_Project/Data_visual_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualization Project for beginners

# %%
# import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the csv file or dataset from google drive
#df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Visualisation Project/VideoGamesSales.csv')
df=pd.read_csv("https://raw.githubusercontent.com/AlkaAttri/Python-ML-Learning/main/Data_Visual_Project/VideoGamesSales.csv")

df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %%
#size of dataset
df.shape
# Out:
# (5909, 15)

# %%
#check if any row is duplicated
df.duplicated().any()
# Out:
# True

# %%
# showing duplicated rows
df_duplicated_rows=df[df.duplicated()]
print(df_duplicated_rows.shape)
df_duplicated_rows
# Out:
# (16, 15)
#       Rank                                               Name Platform  Year  \
# 9        9                          New Super Mario Bros. Wii      Wii  2010
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 11       9                          New Super Mario Bros. Wii      Wii  2010
# 12       9                          New Super Mario Bros. Wii      Wii  2010
# 64      60                                     Super Mario 64       DS  2010
# 65      60                                     Super Mario 64       DS  2010
# 66      60                                     Super Mario 64       DS  2010
# 380    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 382    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1658  1649                                         WCW Mayhem       PS  2015
# ...

# %%
#drop duplicated rows
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (5893, 15)

# %%
df.info()  # one - way to check for null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5893 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5893 non-null   int64
#  1   Name           5893 non-null   object
#  2   Platform       5893 non-null   object
#  3   Year           5893 non-null   int64
#  4   Month          5893 non-null   object
#  5   Genre          5893 non-null   object
#  6   Publisher      5881 non-null   object
#  7   Country        5893 non-null   object
#  8   City           5893 non-null   object
#  9   State          5893 non-null   object
#  10  Region         5866 non-null   object
#  11  NA_Sales       5893 non-null   object
#  12  Global_Sales   5893 non-null   float64
#  13  NA_Profit      5893 non-null   float64
#  14  Global_Profit  5893 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 736.6+ KB

# %%
#other way to check for NaN or null values
filter_na=df.isna().any()
print(filter_na)
filter_na=filter_na.loc[filter_na]
filter_na
# Out:
# Rank             False
# Name             False
# Platform         False
# Year             False
# Month            False
# Genre            False
# Publisher         True
# Country          False
# City             False
# State            False
# Region            True
# NA_Sales         False
# Global_Sales     False
# NA_Profit        False
# Global_Profit    False
# dtype: bool
# Publisher    True
# Region       True
# dtype: bool

# %%
#access the values at specific row and na values
df_na=df[df['Publisher'].isna()]
print(df_na.shape)
df_na
# Out:
# (12, 15)
#       Rank                                               Name Platform  Year  \
# 480    471                         wwe Smackdown vs. Raw 2006      PS2  2010
# 1313  1305                                     Triple Play 99       PS  2013
# 1675  1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA  2011
# 2235  2224                                 Bentley's Hackpack      GBA  2012
# 3172  3161  Nicktoons Collection: Game Boy Advance Video V...      GBA  2012
# 3179  3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA  2012
# 3779  3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA  2014
# 4158  4147                                 Sonic the Hedgehog      PS3  2015
# 4539  4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA  2015
# 4648  4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA  2015
# 5315  5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii  2016
# ...

# %%
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
#df['Publisher'].fillna('OTHER_PUBLISHER',inplace=True)  # The behavior will change in pandas 3.0.
df['Publisher']=df['Publisher'].fillna('OTHER_PUBLISHER')
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'OTHER_PUBLISHER', 'Majesco Entertainment', 'Codemasters',
#        'Red Orb', 'Level 5', 'Arena Entertainment', 'Midway Games', 'JVC',
#        'Deep Silver', '989 Studios', 'NCSoft', 'UEP Systems',
# ...

# %%
df_region_na=df[df['Region'].isna()]
print(df_region_na.shape)
df_region_na
# Out:
# (27, 15)
#       Rank                                       Name Platform  Year Month  \
# 13      10                                  Duck Hunt      NES  2010   Oct
# 38      35                 Call of Duty: Black Ops II      PS3  2010   Nov
# 53      50  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2010   Feb
# 84      78                                    FIFA 16      PS4  2010   Jun
# 126    120                 Uncharted 2: Among Thieves      PS3  2010   Dec
# 210    204        Super Smash Bros. for Wii U and 3DS     WiiU  2010   Dec
# 225    219                           Assassin's Creed      PS3  2010   Mar
# 243    237                             The Last of Us      PS4  2010   Sep
# 2453  2442  Harry Potter and the Order of the Phoenix       DS  2013   May
# 2454  2443                         Rampage World Tour       PS  2013   Jun
# 2455  2444                            Burnout Legends      PSP  2013   Jul
# ...

# %%
df['Region'].unique()
# Out:
# array(['West', 'South', 'Central', 'East', nan, 'Other', 'North'],
#       dtype=object)

# %%
# replace NaN value with 'OTHER' in Region column
df['Region']=df['Region'].fillna('OTHER')
df['Region'].unique()
# Out:
# array(['West', 'South', 'Central', 'East', 'OTHER', 'Other', 'North'],
#       dtype=object)

# %%
df['NA_Sales'].unique()
# Out:
# array(['$41.49', '$29.08', '$15.85', '$15.75', '$11.27', '$23.20',
#        '$11.38', '$14.03', '$14.59', '$26.93', '$9.07', '$9.81', '9',
#        '8.94', '9.09', '14.97', '7.01', '9.43', '12.78', '4.75', '6.42',
#        '10.83', '9.54', '9.63', '8.41', '6.06', '5.57', '3.44', '6.85',
#        '9.03', '5.89', '9.67', '5.17', '5.77', '4.99', '8.25', '8.52',
#        '5.54', '6.99', '6.75', '5.98', '2.55', '4.74', '7.97', '3.8',
#        '4.4', '6.91', '3.01', '6.16', '4.23', '6.76', '4.02', '4.89',
#        '2.96', '4.76', '5.99', '4.34', '5.08', '6.05', '6.72', '7.03',
#        '5.55', '3.66', '6.63', '4.09', '5.84', '3.88', '5.91', '4.36',
#        '5.58', '2.01', '4.46', '5.03', '3.54', '1.11', '1.79', '6.82',
#        '3.81', '2.91', '1.06', '0.98', '5.8', '2.58', '2.28', '2.82',
#        '7.28', '2.9', '2.93', '2.8', '4.1', '3.78', '5.39', '3.24',
#        '4.79', '3.83', '4.52', '3.51', '2.85', '3.27', '3.68', '4.41',
# ...

# %%
#Replace dollar $ sign with  ' ' space
df['NA_Sales']=df['NA_Sales'].replace('[$]',' ',regex=True)
df['NA_Sales']
# Out:
# 0        41.49
# 1        29.08
# 2        15.85
# 3        15.75
# 4        11.27
#          ...
# 5904      0.21
# 5905      0.15
# 5906      0.24
# 5907      0.17
# 5908         0
# Name: NA_Sales, Length: 5893, dtype: object

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Month', 'Genre', 'Publisher',
#        'Country', 'City', 'State', 'Region', 'NA_Sales', 'Global_Sales',
#        'NA_Profit', 'Global_Profit'],
#       dtype='object')

# %%
df['Country'].unique()
# Out:
# array(['United States', 'USA', 'Australia'], dtype=object)

# %%
df['Country']=df['Country'].replace("United States","USA")
df['Country'].unique()
# Out:
# array(['USA', 'Australia'], dtype=object)

# %%
df[df['Country']=="USA"]
# Out:
#       Rank                                               Name Platform  Year  \
# 0        1                                         Wii Sports      Wii  2010
# 1        2                                  Super Mario Bros.      NES  2010
# 2        3                                     Mario Kart Wii      Wii  2010
# 3        4                                  Wii Sports Resort      Wii  2010
# 4        5                           Pokemon Red/Pokemon Blue       GB  2010
# ...    ...                                                ...      ...   ...
# 2793  2782              The Lord of the Rings: The Two Towers      GBA  2015
# 2794  2783                          Tiger Woods PGA Tour 2001      PS2  2015
# 2795  2784               Indiana Jones and the Staff of Kings      Wii  2015
# 2796  2785                                         Jet Moto 3       PS  2015
# 2797  2786  Naruto Shippuden: Ultimate Ninja Storm Generat...      PS3  2015
#
# ...

# %%
# Renaming the coulumns in proper format
df.rename(columns={'NA_Sales':'National Sales', 'Global_Sales':'Global Sales','NA_Profit':"National Profit",'Global_Profit':"Global Profit"},inplace=True)
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Month', 'Genre', 'Publisher',
#        'Country', 'City', 'State', 'Region', 'National Sales', 'Global Sales',
#        'National Profit', 'Global Profit'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Rank               Name Platform  Year Month     Genre Publisher Country  \
# 0     1         Wii Sports      Wii  2010   Jan    Sports  Nintendo     USA
# 1     2  Super Mario Bros.      NES  2010   Feb  Platform  Nintendo     USA
# 2     3     Mario Kart Wii      Wii  2010   Mar    Racing  Nintendo     USA
#
#          City       State Region National Sales  Global Sales  \
# 0   Fairfield  California   West          41.49         82.74
# 1     Edmonds  Washington   West          29.08         40.24
# 2  Louisville    Kentucky  South          15.85         35.82
#
#    National Profit  Global Profit
# 0           12.447         24.822
# 1            8.724         12.072
# 2            4.755         10.746

# %%
#converting the datatype of National Sales column to float
df['National Sales']=df['National Sales'].astype(float)

df.dtypes
# Out:
# Rank                 int64
# Name                object
# Platform            object
# Year                 int64
# Month               object
# Genre               object
# Publisher           object
# Country             object
# City                object
# State               object
# Region              object
# National Sales     float64
# Global Sales       float64
# National Profit    float64
# Global Profit      float64
# dtype: object

# %%
# Total National Sales Region and country wise
df_group=df.groupby(['Region','Country'])['National Sales'].sum()
df_group
# Out:
# Region   Country
# Central  USA           701.44
# East     Australia       1.35
#          USA           812.50
# North    Australia      11.68
# OTHER    Australia       3.56
#          USA            49.35
# Other    Australia      28.21
# South    Australia      16.30
#          USA           507.48
# West     Australia     683.62
#          USA          1020.79
# Name: National Sales, dtype: float64

# %%
#reset index of above Series
df_group=df_group.reset_index()
df_group
# Out:
#      Region    Country  National Sales
# 0   Central        USA          701.44
# 1      East  Australia            1.35
# 2      East        USA          812.50
# 3     North  Australia           11.68
# 4     OTHER  Australia            3.56
# 5     OTHER        USA           49.35
# 6     Other  Australia           28.21
# 7     South  Australia           16.30
# 8     South        USA          507.48
# 9      West  Australia          683.62
# 10     West        USA         1020.79

# %%
# sort the values in decreasing order by Natonal Sales
df_group=df_group.sort_values('National Sales',ascending=False)
df_group
# Out:
#      Region    Country  National Sales
# 10     West        USA         1020.79
# 2      East        USA          812.50
# 0   Central        USA          701.44
# 9      West  Australia          683.62
# 8     South        USA          507.48
# 5     OTHER        USA           49.35
# 6     Other  Australia           28.21
# 7     South  Australia           16.30
# 3     North  Australia           11.68
# 4     OTHER  Australia            3.56
# 1      East  Australia            1.35

# %%
#visualisation using bar graph

import warnings # To suppress some warnings

# Suppress the specific FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

ax=sns.barplot(y='National Sales',x='Region',data=df_group,hue='Country')
# Adding text on the bars
for p in ax.patches:  # ax.patches is a list of the bars
    height = p.get_height()  # Get the height of each bar
    ax.text(
        p.get_x() + p.get_width() / 2,  # x position: center of the bar
        height,  # y position: height of the bar
        round(height, 2),  # Text to display
        ha="center",  # Center horizontally
        va="bottom"  # Place text above the bar
    )

plt.title('National Sales Region and Country wise',{'fontsize':16,'fontweight':'bold','color':'green'})
plt.ylabel('National Sales',{'fontsize':14,'fontweight':'bold','color':'#0000FF'})
plt.xlabel('Region',{'fontsize':14,'fontweight':'bold','color':'#AB4556'})
plt.show()

# %%
#country wise national sales and global sales
df_ns_gs=df.groupby(['Country'])[['National Sales','Global Sales']].sum()
df_ns_gs
# Out:
#            National Sales  Global Sales
# Country
# Australia          744.72       1468.25
# USA               3091.56       6315.68

# %%
df_ns_gs.reset_index(inplace=True)
df_ns_gs
# Out:
#      Country  National Sales  Global Sales
# 0  Australia          744.72       1468.25
# 1        USA         3091.56       6315.68

# %%
#pie chart visualisation
plt.subplot(1,2,1)
plt.pie(df_ns_gs['National Sales'],labels=df_ns_gs['Country'],autopct='%.2f%%',startangle=90,colors="gy")
plt.title('National Sales')

plt.subplot(1,2,2)
plt.pie(df_ns_gs['Global Sales'],labels=df_ns_gs['Country'],autopct='%.2f%%',startangle=270)
plt.title('Global Sales')
# Out:
# Text(0.5, 1.0, 'Global Sales')

# %%
#find year-wise Global Profit and National Profit
df_gf_nf_year=df.groupby(['Year'])[['Global Profit','National Profit']].sum()
df_gf_nf_year
# Out:
#       Global Profit  National Profit
# Year
# 2010       1119.432          538.692
# 2011        367.497          184.395
# 2012        294.687          147.387
# 2013        127.947           64.206
# 2014        143.298           71.103
# 2015        164.610           86.247
# 2016         69.825           35.067
# 2017         47.883           23.787

# %%
# create a dataframe
df_gf_nf_year.reset_index(inplace=True)
df_gf_nf_year
# Out:
#    Year  Global Profit  National Profit
# 0  2010       1119.432          538.692
# 1  2011        367.497          184.395
# 2  2012        294.687          147.387
# 3  2013        127.947           64.206
# 4  2014        143.298           71.103
# 5  2015        164.610           86.247
# 6  2016         69.825           35.067
# 7  2017         47.883           23.787

# %%
#line Chart
plt.plot(df_gf_nf_year['Year'],df_gf_nf_year['Global Profit'],label='Global Profit',marker="s")
plt.plot(df_gf_nf_year['Year'],df_gf_nf_year['National Profit'],label='National Profit',marker='o')
plt.legend()
plt.xlabel('Year',{'fontsize':14,'fontweight':'bold','color':'#AB4556'})
plt.ylabel('Profit',{'fontsize':14,'fontweight':'bold','color':'#AB00FF'})
plt.show()

# %%
#find Genre
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
#show the genre -wise National Sales
df_genre=df.groupby(['Genre'])[['National Sales','Global Sales']].sum().reset_index().sort_values('National Sales',ascending=False)
df_genre
# Out:
#            Genre  National Sales  Global Sales
# 0         Action          762.97       1523.52
# 10        Sports          592.32       1158.67
# 8        Shooter          540.75        960.94
# 4       Platform          415.07        777.96
# 3           Misc          339.25        678.70
# 6         Racing          309.95        644.88
# 7   Role-Playing          293.20        820.87
# 2       Fighting          200.37        391.56
# 9     Simulation          150.87        333.34
# 5         Puzzle          101.56        206.42
# 1      Adventure           75.92        158.12
# 11      Strategy           54.05        128.95

# %%
#Bar-Chart showing Genre-wise National Sales
ax=sns.barplot(y='Genre',x='National Sales',data=df_genre,hue="Genre")
# Adding text on the horizontal bars
for p in ax.patches:
    width = p.get_width()  # Get the width of each bar (i.e., the value)
    ax.text(
        width,  # x position: end of the bar
        p.get_y() + p.get_height() / 2,  # y position: center of the bar
        round(width, 2),  # Text to display (rounded value)
        ha='left',  # Align text to the left of the bar's end
        va='center',  # Center text vertically along the bar
        color='brown'
    )
plt.title('Genre -Wise National Sales',{'fontsize':14,'fontweight':'bold'})
plt.xlabel('National Sales')
plt.ylabel('Genre')
plt.show()

# %%
ax=sns.barplot(y='Genre',x='Global Sales',data=df_genre.sort_values('Global Sales',ascending=False))
# Adding text on the horizontal bars
for p in ax.patches:
    width = p.get_width()  # Get the width of each bar (i.e., the value)
    ax.text(
        width,  # x position: end of the bar
        p.get_y() + p.get_height() / 2,  # y position: center of the bar
        round(width, 2),  # Text to display (rounded value)
        ha='left',  # Align text to the left of the bar's end
        va='center',  # Center text vertically along the bar
        color='brown'
    )

plt.title('Genre -Wise Global Sales',{'fontsize':14,'fontweight':'bold'})
plt.xlabel('Global Sales')
plt.ylabel('Genre')
plt.show()

# %%
sns.barplot(y="Genre", x="National Sales", hue="Global Sales", data=df_genre)
# Out:
# <Axes: xlabel='National Sales', ylabel='Genre'>

# %%
#stacked bar chart
bar1=plt.barh(df_genre['Genre'],df_genre['Global Sales'],label='Global Sales',color='brown')
bar2=plt.barh(df_genre['Genre'],df_genre['National Sales'],label='National Sales',color='r')
for bar in bar1:
    width = bar.get_width()  # Get width of the bar (i.e., sales value)
    plt.text(
        width,  # x position: width of the bar
        bar.get_y() + bar.get_height()/2,  # y position: center of the bar
        round(width, 2),  # Text to display (rounded sales value)
        ha='left',  # Align text to the left of the bar's end
        va='center',  # Center text vertically along the bar
        color='maroon' #set the color
    )
for bar in bar2:
    width = bar.get_width()  # Get width of the bar (i.e., sales value)
    plt.text(
        width,  # x position: width of the bar
        bar.get_y() + bar.get_height()/2,  # y position: center of the bar
        round(width, 2),  # Text to display (rounded sales value)
        ha='center',  # Align text to the center of the bar's end
        va='center' # Center text vertically along the bar

    )
plt.legend()
plt.ylabel('Genre',{'fontsize':14,'fontweight':'bold','color':'#AB4556'})
plt.xlabel('Sales',{'fontsize':14,'fontweight':'bold','color':'#AB00FF'})

plt.show()

# %%
#Multi-coulmn barchart
barWidth=0.4
df_genre_sorted=df_genre.sort_values('Global Sales').reset_index()

bar1=plt.barh(df_genre_sorted['Genre'],df_genre_sorted['Global Sales'],barWidth,label='Global Sales',color='g',)
bar2=plt.barh(np.arange(len(df_genre_sorted['Genre']))+barWidth,df_genre_sorted['National Sales'],barWidth,label='National Sales',color='brown')
plt.legend()

for bar in bar1:
    width = bar.get_width()  # Get width of the bar (i.e., sales value)
    plt.text(
        width,  # x position: width of the bar
        bar.get_y() + bar.get_height()/2,  # y position: center of the bar
        round(width, 2),  # Text to display (rounded sales value)
        ha='left',  # Align text to the left of the bar's end
        va='center',  # Center text vertically along the bar
        color='maroon' #set the color
    )
for bar in bar2:
    width = bar.get_width()  # Get width of the bar (i.e., sales value)
    plt.text(
        width,  # x position: width of the bar
        bar.get_y() + bar.get_height()/2,  # y position: center of the bar
        round(width, 2),  # Text to display (rounded sales value)
        ha='left',  # Align text to the left of the bar's end
        va='center' # Center text vertically along the bar


    )
plt.ylabel('Genre',{'fontsize':14,'fontweight':'bold','color':'#AB4556'})
plt.xlabel('Sales',{'fontsize':14,'fontweight':'bold','color':'#AB00FF'})

plt.show()
